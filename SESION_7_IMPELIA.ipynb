# %% [markdown]
# <a href="https://colab.research.google.com/github/otrocarlosmartinez/AF-PYTHON/blob/main/SESION_7_IMPELIA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - Filtrar personas mayores de 20 años.
# - Ordenar la serie por edad en orden ascendente.
# - Ordenar la serie por nombre en orden descendente.
# - Mostrar solo los nombres de personas cuyo nombre comience con la letra 'M'.
# - Calcular la media de las edades de los mayores de 20

# %%
import pandas as pd
import numpy as np

# %%
# Define a list of possible first names
first_names = ["Alice", "Bob", "Charlie", "Dave", "Eve", "Jona", "Katie", "Liam", "Mia", "Noah", "Olivia", "Peter", "Quinn", "Ryan", "Sophia", "Thomas", "Ursula", "Vincent", "Wendy", "Xavier"]

# %%
# Generate 20 random ages between 18 and 65
ages = np.random.randint(18, 66, size=20)

# %%
# Create a dictionary with first names as keys and ages as values
name_age_dict = {name: age for name, age in zip(first_names, ages)}

# %%
name_age_dict
# Out:
# {'Alice': 61,
#  'Bob': 58,
#  'Charlie': 53,
#  'Dave': 65,
#  'Eve': 51,
#  'Jona': 61,
#  'Katie': 58,
#  'Liam': 62,
#  'Mia': 48,
#  'Noah': 55,
#  'Olivia': 20,
#  'Peter': 42,
#  'Quinn': 43,
#  'Ryan': 39,
#  'Sophia': 50,
#  'Thomas': 19,
#  'Ursula': 48,
#  'Vincent': 55,
#  'Wendy': 29,
#  'Xavier': 47}

# %%
name_age_serie = pd.Series(name_age_dict)

# %%
name_age_serie
# Out:
# Alice      61
# Bob        58
# Charlie    53
# Dave       65
# Eve        51
# Jona       61
# Katie      58
# Liam       62
# Mia        48
# Noah       55
# Olivia     20
# Peter      42
# Quinn      43
# Ryan       39
# Sophia     50
# Thomas     19
# Ursula     48
# Vincent    55
# Wendy      29
# Xavier     47
# dtype: int64

# %%
name_age_serie[name_age_serie>20]
# Out:
# Alice      61
# Bob        58
# Charlie    53
# Dave       65
# Eve        51
# Jona       61
# Katie      58
# Liam       62
# Mia        48
# Noah       55
# Peter      42
# Quinn      43
# Ryan       39
# Sophia     50
# Ursula     48
# Vincent    55
# Wendy      29
# Xavier     47
# dtype: int64

# %%
name_age_serie.sort_values()
# Out:
# Thomas     19
# Olivia     20
# Wendy      29
# Ryan       39
# Peter      42
# Quinn      43
# Xavier     47
# Ursula     48
# Mia        48
# Sophia     50
# Eve        51
# Charlie    53
# Vincent    55
# Noah       55
# Katie      58
# Bob        58
# Jona       61
# Alice      61
# Liam       62
# Dave       65
# dtype: int64

# %%
name_age_serie.sort_values(ascending=False)
# Out:
# Dave       65
# Liam       62
# Alice      61
# Jona       61
# Katie      58
# Bob        58
# Noah       55
# Vincent    55
# Charlie    53
# Eve        51
# Sophia     50
# Mia        48
# Ursula     48
# Xavier     47
# Quinn      43
# Peter      42
# Ryan       39
# Wendy      29
# Olivia     20
# Thomas     19
# dtype: int64

# %%
name_age_serie[name_age_serie.index.str.startswith("M")]
# Out:
# Mia    48
# dtype: int64

# %%
name_age_serie[name_age_serie>20].mean()
# Out:
# 51.388888888888886

# %% [markdown]
# # EJERCICIO
# Se le proporcionan dos df que contienen datos de ventas de una empresa en diferentes regiones y categorías. El primer marco de datos contiene datos de ventas de enero y el segundo marco de datos contiene datos de ventas de febrero.
#
# Datos de enero:
#
# # Datos de ventas de enero
# data_january = {
# 'Región': ['Norte', 'Norte', 'Este', 'Este', 'Sur', 'Sur', 'Oeste', 'Oeste'],
# 'Categoría': ['Electrónica', 'Muebles', 'Electrónica', 'Muebles', 'Electrónica', 'Muebles', 'Electrónica', 'Muebles'],
# 'Ventas': [5000, 7000, 3000, 10000, 2000, 1500, 6000, 8000]
# }
# df_january = pd.DataFrame(data_january)
#
# Datos de febrero:
#
# # Datos de ventas de febrero
# data_february = {
# 'Región': ['Norte', 'Norte', 'Este', 'Este', 'Sur', 'Sur', 'Oeste', 'Oeste'],
# 'Categoría': ['Electrónica', 'Muebles', 'Electrónica', 'Muebles', 'Electrónica', 'Muebles', 'Electrónica', 'Muebles'],
# 'Ventas': [4000, 6000, 2000, 12000, 2500, 1700, 5500, 9000]
# }
# df_february = pd.DataFrame(data_february)
#
# Tareas:
#
# - Concatenar los DataFrames: Concatenar los DataFrames de enero y febrero en un único DataFrame.
#
# - Filtrar los datos: Filtrar las filas en las que las ventas sean mayores a 5000.
#
# - Agrupar por y agregar: Agrupar los datos filtrados por región y categoría, y calcular las ventas totales por grupo.
#
# - Ordenar los datos: Ordenar el DataFrame resultante por ventas en orden descendente.

# %%
# Datos de ventas de enero
data_january = {
'Región': ['Norte', 'Norte', 'Este', 'Este', 'Sur', 'Sur', 'Oeste', 'Oeste'],
'Categoría': ['Electrónica', 'Muebles', 'Electrónica', 'Muebles', 'Electrónica', 'Muebles', 'Electrónica', 'Muebles'],
'Ventas': [5000, 7000, 3000, 10000, 2000, 1500, 6000, 8000]
}
df_january = pd.DataFrame(data_january)

# %%
# Datos de ventas de febrero
data_february = {
'Región': ['Norte', 'Norte', 'Este', 'Este', 'Sur', 'Sur', 'Oeste', 'Oeste'],
'Categoría': ['Electrónica', 'Muebles', 'Electrónica', 'Muebles', 'Electrónica', 'Muebles', 'Electrónica', 'Muebles'],
'Ventas': [4000, 6000, 2000, 12000, 2500, 1700, 5500, 9000]
}
df_february = pd.DataFrame(data_february)

# %%
df_january
# Out:
#   Región    Categoría  Ventas
# 0  Norte  Electrónica    5000
# 1  Norte      Muebles    7000
# 2   Este  Electrónica    3000
# 3   Este      Muebles   10000
# 4    Sur  Electrónica    2000
# 5    Sur      Muebles    1500
# 6  Oeste  Electrónica    6000
# 7  Oeste      Muebles    8000

# %%
df_february
# Out:
#   Región    Categoría  Ventas
# 0  Norte  Electrónica    4000
# 1  Norte      Muebles    6000
# 2   Este  Electrónica    2000
# 3   Este      Muebles   12000
# 4    Sur  Electrónica    2500
# 5    Sur      Muebles    1700
# 6  Oeste  Electrónica    5500
# 7  Oeste      Muebles    9000

# %%
df_concat = pd.concat([df_january,df_february])

# %%
df_concat
# Out:
#   Región    Categoría  Ventas
# 0  Norte  Electrónica    5000
# 1  Norte      Muebles    7000
# 2   Este  Electrónica    3000
# 3   Este      Muebles   10000
# 4    Sur  Electrónica    2000
# 5    Sur      Muebles    1500
# 6  Oeste  Electrónica    6000
# 7  Oeste      Muebles    8000
# 0  Norte  Electrónica    4000
# 1  Norte      Muebles    6000
# 2   Este  Electrónica    2000
# 3   Este      Muebles   12000
# 4    Sur  Electrónica    2500
# 5    Sur      Muebles    1700
# 6  Oeste  Electrónica    5500
# 7  Oeste      Muebles    9000

# %%
df_concat[df_concat["Ventas"]>5000]
# Out:
#   Región    Categoría  Ventas
# 1  Norte      Muebles    7000
# 3   Este      Muebles   10000
# 6  Oeste  Electrónica    6000
# 7  Oeste      Muebles    8000
# 1  Norte      Muebles    6000
# 3   Este      Muebles   12000
# 6  Oeste  Electrónica    5500
# 7  Oeste      Muebles    9000

# %%
df_concat.groupby(["Región","Categoría"])["Ventas"].sum()
# Out:
# Región  Categoría
# Este    Electrónica     5000
#         Muebles        22000
# Norte   Electrónica     9000
#         Muebles        13000
# Oeste   Electrónica    11500
#         Muebles        17000
# Sur     Electrónica     4500
#         Muebles         3200
# Name: Ventas, dtype: int64

# %%
df_concat.groupby(["Región","Categoría"])["Ventas"].sum().sort_values(ascending=False)
# Out:
# Región  Categoría
# Este    Muebles        22000
# Oeste   Muebles        17000
# Norte   Muebles        13000
# Oeste   Electrónica    11500
# Norte   Electrónica     9000
# Este    Electrónica     5000
# Sur     Electrónica     4500
#         Muebles         3200
# Name: Ventas, dtype: int64

# %% [markdown]
# Recuento de personas que vivieron por clase

# %%
df=pd.read_csv('https://raw.githubusercontent.com/jorloicono/AF-PYTHON/refs/heads/main/DATOS/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.groupby("Pclass")["PassengerId"].count().sort_values(ascending=False)
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: PassengerId, dtype: int64

# %%
ax = df.groupby("Pclass")["PassengerId"].count().sort_values(ascending=False).plot(kind="bar")
total = len(df)
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2 - 0.1
    y = p.get_y() + p.get_height()
    ax.annotate(f'{p.get_height()}\n({percentage})', (x, y), size = 12)

# %%
total
# Out:
# 891

# %%
df[df['Survived']==1].groupby("Pclass")["PassengerId"].count()
# Out:
# Pclass
# 1    136
# 2     87
# 3    119
# Name: PassengerId, dtype: int64

# %%
df.groupby(["Pclass", "Survived"]).size().unstack()
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
df.groupby(["Pclass", "Survived"]).size().unstack().plot(kind = "bar", stacked = True, title = "Número de personas fallecidas y supervivientes por clase")
# Out:
# <Axes: title={'center': 'Número de personas fallecidas y supervivientes por clase'}, xlabel='Pclass'>

# %%
df.groupby(["Sex", "Survived"]).size().unstack().plot(kind = "bar", stacked = True, title = "Número de personas fallecidas y supervivientes por clase")
# Out:
# <Axes: title={'center': 'Número de personas fallecidas y supervivientes por clase'}, xlabel='Sex'>
